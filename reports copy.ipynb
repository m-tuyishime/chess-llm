# %%
from modules import ReportGenerator

gen = ReportGenerator()

# %%
gen.rating_trends()

# %%
gen.rating_deviation_trends()

# %%
gen.puzzle_outcome()

# %%
gen.puzzle_outcomes_by_agent()

# %%
gen.illegal_moves_distribution()

# %%
gen.final_ratings_intervals()

# %%
gen.correct_moves_percentage()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 gen.correct_moves_percentage()
#
# File /app/modules/report_generator.py:245, in ReportGenerator.correct_moves_percentage(self)
#     243 # Calculate percentage of moves provided
#     244 if len(agent_moves) > num_expected:
# --> 245     raise ValueError(f"Model moves for puzzle {idx} exceed expected moves.")
#     246 correct_pct = (len(agent_moves) / num_expected) * 100
#     248 results.append({"agent_name": row["agent_name"], "correct_pct": correct_pct})
#
# ValueError: Model moves for puzzle 4155 exceed expected moves.

# %%
gen.token_usage_per_move()

# %%
gen.token_usage_per_puzzle()

# %%
gen.success_percentage_by_theme_rating_bins()
