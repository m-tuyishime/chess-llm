# %%
from modules import *

gen = ReportGenerator()
# Out:
# 2025-03-25 00:56:25,781 - chess_benchmark.database - INFO - Initializing database at data/storage.db
# 2025-03-25 00:56:25,807 - chess_benchmark.database - INFO - Database tables created/verified
# 2025-03-25 00:56:25,809 - chess_benchmark.database - INFO - Database initialized successfully

# %%
gen.generate_model_rating_trends()

# %%
gen.generate_model_deviation_trends()

# %%
gen.generate_puzzle_outcome_report()

# %%
gen.generate_puzzle_outcomes_by_model_subplots()

# %%
gen.generate_illegal_moves_distribution()

# %%
gen.generate_final_ratings_intervals()

# %%
gen.generate_correct_moves_percentage_report()
