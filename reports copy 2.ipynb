# %%
from modules import ReportGenerator

gen = ReportGenerator()

# %%
gen.generate_model_rating_trends()

# %%
gen.generate_model_deviation_trends()

# %%
gen.generate_puzzle_outcome_report()

# %%
gen.generate_puzzle_outcomes_by_model_subplots()

# %%
gen.generate_illegal_moves_distribution()

# %%
gen.generate_final_ratings_intervals()

# %%
gen.generate_correct_moves_percentage_report()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 gen.generate_correct_moves_percentage_report()
#
# File /app/modules/report_generator.py:231, in ReportGenerator.generate_correct_moves_percentage_report(self)
#     229 # Calculate percentage of moves provided
#     230 if len(model_moves) > num_expected:
# --> 231     raise ValueError(f"Model moves for puzzle {idx} exceed expected moves.")
#     232 correct_pct = (len(model_moves) / num_expected) * 100
#     234 results.append({"model_name": row["model_name"], "correct_pct": correct_pct})
#
# ValueError: Model moves for puzzle 0 exceed expected moves.

# %%
gen.generate_token_usage_per_move_report()

# %%
gen.generate_token_usage_per_puzzle_report()

# %%
gen.generate_successes_by_theme_rating_bins_report()
